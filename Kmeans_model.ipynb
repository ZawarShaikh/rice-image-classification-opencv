# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pylab as plt 
# %matplotlib inline

# %%
df = pd.read_csv(r'Rice_MSC_Dataset.csv')
df.head(5)
# Out:
#    AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  7805    437.915    209.8215     48.0221        0.9735   99.6877    0.9775
# 1  7503    340.757    138.3361     69.8417        0.8632   97.7400    0.9660
# 2  5124    314.617    141.9803     46.5784        0.9447   80.7718    0.9721
# 3  7990    437.085    201.4386     51.2245        0.9671  100.8622    0.9659
# 4  7433    342.893    140.3350     68.3927        0.8732   97.2830    0.9831
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  ALLdaub4b  \
# 0         7985  0.3547        4.3693  ...   113.9924    65.0610    59.5989
# 1         7767  0.6637        1.9807  ...   105.7055    64.3685    62.2084
# 2         5271  0.4760        3.0482  ...   109.7155    62.6423    58.7439
# 3         8272  0.6274        3.9325  ...   116.5405    64.9069    60.2562
# 4         7561  0.6006        2.0519  ...   107.7502    64.7071    61.3549
#
# ...

# %%
plt.scatter(df['AREA'], df['CLASS'])

# %%
plt.scatter(df['PERIMETER'], df['CLASS'])

# %%
#Kmeans_Model

# %%
km = KMeans(n_clusters=5)
km
# Out:
# KMeans(n_clusters=5)

# %%
X = df.drop('CLASS', axis=1)
y = pd.DataFrame()
y = df['CLASS']

# %%
X
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0       7805    437.915    209.8215     48.0221        0.9735   99.6877
# 1       7503    340.757    138.3361     69.8417        0.8632   97.7400
# 2       5124    314.617    141.9803     46.5784        0.9447   80.7718
# 3       7990    437.085    201.4386     51.2245        0.9671  100.8622
# 4       7433    342.893    140.3350     68.3927        0.8732   97.2830
# ...      ...        ...         ...         ...           ...       ...
# 74995   5551    285.911    114.1695     62.9079        0.8345   84.0699
# 74996   7696    322.703    121.3900     81.1375        0.7438   98.9892
# 74997   7579    339.295    136.3125     71.2866        0.8524   98.2338
# 74998  15174    489.502    200.9486     97.6282        0.8740  138.9969
# 74999  12931    452.635    185.5138     90.2651        0.8736  128.3131
#
#        SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  \
# ...

# %%
y
# Out:
# 0          Basmati
# 1          Arborio
# 2          Jasmine
# 3          Basmati
# 4          Arborio
#            ...
# 74995      Arborio
# 74996    Karacadag
# 74997      Arborio
# 74998       Ipsala
# 74999       Ipsala
# Name: CLASS, Length: 74992, dtype: object

# %%
df.dropna(inplace=True)

# %%
X.dropna(inplace=True)

# %%
from sklearn.impute import SimpleImputer

# Create the imputer object
imputer = SimpleImputer(strategy='mean')

# Fit and transform the dataframe to fill in missing values
imputed_data = imputer.fit_transform(X)

# %%
y_predicted = km.fit_predict(X, y)
y_predicted
# Out:
# C:\Users\Zawwar\anaconda3_new\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 4, 0, ..., 4, 1, 3])

# %%
df['cluster'] = y_predicted
df.head()
# Out:
#    AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  7805    437.915    209.8215     48.0221        0.9735   99.6877    0.9775
# 1  7503    340.757    138.3361     69.8417        0.8632   97.7400    0.9660
# 2  5124    314.617    141.9803     46.5784        0.9447   80.7718    0.9721
# 3  7990    437.085    201.4386     51.2245        0.9671  100.8622    0.9659
# 4  7433    342.893    140.3350     68.3927        0.8732   97.2830    0.9831
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4a  ALLdaub4b  ALLdaub4Y  \
# 0         7985  0.3547        4.3693  ...    65.0610    59.5989   104.8552
# 1         7767  0.6637        1.9807  ...    64.3685    62.2084    96.8375
# 2         5271  0.4760        3.0482  ...    62.6423    58.7439   100.2352
# 3         8272  0.6274        3.9325  ...    64.9069    60.2562   107.2560
# 4         7561  0.6006        2.0519  ...    64.7071    61.3549    98.8704
#
# ...

# %%
df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]
df4 = df[df.cluster == 3]
df5 = df[df.cluster == 4]

# %%
df1.head()
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  EQDIASQ  SOLIDITY  \
# 2   5124    314.617    141.9803     46.5784        0.9447  80.7718    0.9721
# 8   5450    320.362    139.9963     50.6910        0.9321  83.3016    0.9626
# 9   6781    307.023    116.2443     74.8093        0.7654  92.9184    0.9819
# 13  6208    300.124    113.9325     70.6069        0.7848  88.9060    0.9658
# 15  6276    288.886    108.0128     74.3469        0.7254  89.3916    0.9866
#
#     CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4a  ALLdaub4b  ALLdaub4Y  \
# 2          5271  0.4760        3.0482  ...    62.6423    58.7439   100.2352
# 8          5662  0.5502        2.7618  ...    64.9443    60.6481    96.0847
# 9          6906  0.7208        1.5539  ...    66.1287    57.6591    94.9933
# 13         6428  0.7630        1.6136  ...    65.6016    57.9108    92.0734
# 15         6361  0.7821        1.4528  ...    65.2161    59.2272    95.3793
#
# ...

# %%
plt.scatter(df1['cluster'], df1['AREA'], c='green')
plt.scatter(df2['cluster'], df2['AREA'], c='blue')
plt.scatter(df3['cluster'], df3['AREA'], c='red')
plt.scatter(df4['cluster'], df4['AREA'], c='brown')
plt.scatter(df5['cluster'], df5['AREA'], c='yellow')

# %%
df.head()
# Out:
#    AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  7805    437.915    209.8215     48.0221        0.9735   99.6877    0.9775
# 1  7503    340.757    138.3361     69.8417        0.8632   97.7400    0.9660
# 2  5124    314.617    141.9803     46.5784        0.9447   80.7718    0.9721
# 3  7990    437.085    201.4386     51.2245        0.9671  100.8622    0.9659
# 4  7433    342.893    140.3350     68.3927        0.8732   97.2830    0.9831
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4a  ALLdaub4b  ALLdaub4Y  \
# 0         7985  0.3547        4.3693  ...    65.0610    59.5989   104.8552
# 1         7767  0.6637        1.9807  ...    64.3685    62.2084    96.8375
# 2         5271  0.4760        3.0482  ...    62.6423    58.7439   100.2352
# 3         8272  0.6274        3.9325  ...    64.9069    60.2562   107.2560
# 4         7561  0.6006        2.0519  ...    64.7071    61.3549    98.8704
#
# ...

# %%
import numpy as np
from sklearn.cluster import KMeans


# Convert the dataframe to a NumPy array
image_data = X.values

# %%
ground_truth_labels = df['cluster'].values
ground_truth_labels
# Out:
# array([2, 4, 0, ..., 4, 1, 3])

# %%
type(image_data)
# Out:
# numpy.ndarray

# %%
# Create a KMeans object with the desired number of clusters
num_clusters = 5  # Adjust this value based on your requirements
kmeans = KMeans(n_clusters=num_clusters)

# Perform K-means clustering on the image data
kmeans.fit(image_data)
# Out:
# C:\Users\Zawwar\anaconda3_new\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
# Get the cluster labels assigned to each data point
predicted_labels = kmeans.labels_

# Get the cluster centers (centroids)
centroids = kmeans.cluster_centers_

# Print the cluster labels assigned to each data point
print("Cluster Labels:")
print(labels)

# Print the coordinates of the cluster centers (centroids)
print("Cluster Centroids:")
print(centroids)
# Out:
# Cluster Labels:
# [2 2 0 ... 2 3 1]
# Cluster Centroids:
# [[ 5.92465196e+03  3.13658812e+02  1.31959336e+02  5.94863856e+01
#    8.64369403e-01  8.67274823e+01  9.77032433e-01  6.06186703e+03
#    6.48218701e-01  2.37827244e+00  7.68507163e-01  6.72889684e-01
#    2.26790862e-02  9.97915569e-03  4.65712013e-01  9.86171024e-01
#    2.06194649e+02  2.07075522e+02  2.21458176e+02  1.53823247e+01
#    1.54929805e+01  1.63486609e+01 -1.67245608e+00 -1.74316534e+00
#   -2.09296585e+00  1.09379408e+01  1.11317675e+01  1.22221167e+01
#   -2.70063230e+09 -2.72419663e+09 -3.16461080e+09  6.48233128e-01
#    7.14767632e-02  8.68859134e-01  4.45938140e-02  1.71424788e-02
#    6.38540277e-02 -7.24058415e+00 -4.58478366e-01 -2.09634662e+00
#    1.94493567e+02  4.70652391e+00  1.22755972e+01  2.09965955e+03
#    1.82732751e+02  1.17064381e+03  2.12567147e+02  1.29708206e+02
#    1.20696245e+02  1.43520123e+01  9.05592651e-01  2.08368768e+00
# ...

# %%
labels
# Out:
# array([2, 2, 0, ..., 2, 3, 1])

# %%
from sklearn.metrics import accuracy_score

# Create a scatter plot to visualize the clusters
plt.scatter(image_data[:, 0], image_data[:, 1], c=predicted_labels)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='red')
plt.title('K-means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# Evaluate the model's accuracy if ground truth labels are available
if ground_truth_labels is not None:
    accuracy = accuracy_score(ground_truth_labels, predicted_labels)
    print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3670658203541711

# %%
#By using sampling method

# %%
# Taking a random sample of 1000 rows from the dataframe
sample_df = df.sample(n=1000, random_state=42)

# %%
X_sample = sample_df.drop('CLASS', axis=1)
y_sample = pd.DataFrame()
y_sample = sample_df['CLASS']

# %%
import numpy as np
from sklearn.cluster import KMeans


# Convert the dataframe to a NumPy array

sample_image_data = X_sample.values

# %%
sample_ground_truth_labels = sample_df['cluster'].values
sample_ground_truth_labels
# Out:
# array([4, 4, 3, 0, 2, 0, 3, 4, 0, 0, 0, 2, 4, 2, 4, 0, 1, 2, 0, 0, 3, 4,
#        2, 4, 4, 0, 0, 0, 4, 4, 3, 0, 3, 4, 4, 2, 2, 4, 1, 3, 4, 4, 0, 0,
#        3, 0, 4, 4, 0, 4, 3, 0, 0, 4, 4, 4, 1, 4, 0, 0, 0, 4, 1, 0, 0, 0,
#        4, 4, 1, 0, 0, 4, 0, 3, 3, 2, 0, 4, 0, 2, 0, 1, 0, 4, 2, 4, 4, 4,
#        4, 4, 2, 2, 2, 4, 2, 0, 0, 4, 0, 1, 2, 0, 4, 2, 3, 0, 4, 1, 4, 1,
#        0, 0, 2, 1, 0, 2, 4, 4, 4, 3, 0, 1, 0, 0, 4, 3, 0, 0, 2, 0, 0, 4,
#        1, 3, 1, 0, 1, 3, 0, 1, 0, 0, 4, 0, 0, 4, 1, 1, 0, 0, 0, 0, 0, 4,
#        4, 0, 0, 0, 3, 2, 0, 0, 4, 2, 0, 1, 0, 3, 1, 1, 2, 4, 0, 0, 0, 2,
#        4, 1, 1, 0, 1, 0, 0, 2, 0, 2, 0, 4, 4, 4, 2, 2, 0, 0, 4, 4, 0, 1,
#        4, 0, 3, 4, 2, 4, 1, 0, 0, 0, 4, 0, 4, 4, 1, 1, 4, 0, 2, 0, 1, 2,
#        0, 0, 4, 0, 0, 0, 4, 0, 1, 0, 2, 0, 4, 4, 2, 4, 4, 2, 2, 0, 4, 0,
#        1, 0, 3, 1, 0, 0, 1, 4, 0, 4, 3, 0, 3, 4, 0, 2, 2, 1, 4, 3, 4, 4,
#        4, 3, 0, 4, 4, 4, 4, 1, 4, 4, 4, 4, 1, 0, 0, 0, 4, 4, 3, 3, 0, 3,
# ...

# %%
# Create a KMeans object with the desired number of clusters
num_clusters = 5  # Adjust this value based on your requirements
kmeans = KMeans(n_clusters=num_clusters)

# Perform K-means clustering on the image data
kmeans.fit(sample_image_data)
# Out:
# C:\Users\Zawwar\anaconda3_new\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
# Get the cluster labels assigned to each data point
sample_predicted_labels = kmeans.labels_

# Get the cluster centers (centroids)
sample_centroids = kmeans.cluster_centers_

# Print the cluster labels assigned to each data point
print("Cluster Labels:")
print(labels)

# Print the coordinates of the cluster centers (centroids)
print("Cluster Centroids:")
print(centroids)
# Out:
# Cluster Labels:
# [2 2 0 ... 2 3 1]
# Cluster Centroids:
# [[ 5.92906371e+03  3.14870994e+02  1.32892024e+02  5.92205357e+01
#    8.66104986e-01  8.67598679e+01  9.77149861e-01  6.06563435e+03
#    6.41403601e-01  2.41939834e+00  7.64784488e-01  6.69695291e-01
#    2.28362881e-02  9.92049861e-03  4.62064543e-01  9.86594460e-01
#    2.07011016e+02  2.07655537e+02  2.22191237e+02  1.52689338e+01
#    1.53370030e+01  1.62103571e+01 -1.68550028e+00 -1.75509474e+00
#   -2.13013878e+00  1.11480845e+01  1.13625488e+01  1.25622607e+01
#   -2.72402788e+09 -2.74127262e+09 -3.18851167e+09  6.47320499e-01
#    7.10398892e-02  8.71717175e-01  4.56819945e-02  1.76072022e-02
#    6.33448753e-02 -7.61847784e+00 -4.71788920e-01 -2.13371939e+00
#    2.08970459e+02  4.64981884e+00  1.26093036e+01  2.09316776e+03
#    1.82338686e+02  1.15174050e+03  2.13153468e+02  1.29811280e+02
#    1.20653250e+02  1.42097953e+01  9.13207479e-01  2.13691330e+00
# ...

# %%
from sklearn.metrics import accuracy_score

# Create a scatter plot to visualize the clusters
plt.scatter(sample_image_data[:, 0], sample_image_data[:, 1], c=sample_predicted_labels)
plt.scatter(sample_centroids[:, 0], sample_centroids[:, 1], marker='x', color='red')
plt.title('K-means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# Evaluate the model's accuracy if ground truth labels are available
if ground_truth_labels is not None:
    accuracy = accuracy_score(sample_ground_truth_labels, sample_predicted_labels)
    print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.363
